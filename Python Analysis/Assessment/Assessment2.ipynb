# %% [markdown]
# '''
# INSIGHTS TAKEN:-
# 1. The heart disease is rare but as risky also.
# 2. The heart disease is responsible on the factors like age,amoke,alcohol.
# 3. The disease is independent of the factors like weight,height,sys_dia_BP,cholesterol,glucose
# 4. The more fit the person the less prone of the heart disease.
# 5. It targets the one who with more age.
# 6. Overall in order to prevent the risk of this disease the person has to focus on his health and avoid any kind of practises like smoking,alcohol.
# '''
